# %%
import os
import sys
sys.path.append(os.path.abspath(os.path.join(os.pardir, 'src')))
from data_processing import *
# Out:
# 27-Nov-25 12:17:05 - bfio.backends - WARNING  - Java backend is not available. This could be due to a missing dependency (jpype).

# %% [markdown]
# -1) This runs at the leica-env
# 0) Use the loader2 function to extract images from Leica file system
# 1) Launch napari (in a different terminal start micro-sam conda env and there launch Napari).
# 2) Load images in Napari: File, Load Files as Stack...
# 3) Find the frames where MB is visible.
# 4) Make masks out of these selected frames by:
#     a)

# %%
loader2('2025_11_24','Gerardo',True)
# Out:
# Number of series: 4
# series 0: shape = (1, 1, 1, 512, 512)
# series 1: shape = (1, 1, 1, 512, 512)
# series 2: shape = (1, 3, 111, 512, 512)
# series 3: shape = (1, 3, 110, 512, 512)
