# %%
date = '2026_06_25'
ch = '2'
sr = '0'

viewer.open(f'/Users/gerard/data/confocal/{date}_Carmina/series_{sr}/channel_{ch}/{date}_s{sr}_ch{ch}_deconv2d_iter_2.tif')
viewer.open(f'/Users/gerard/data/confocal/{date}_Carmina/series_{sr}/channel_{ch}/{date}_s{sr}_ch{ch}.tif')

viewer.open(f'/Users/gerard/data/confocal/{date}_Carmina/series_{sr}/channel_{ch}/{date}_s{sr}_ch{ch}_deconv2d_iter_2_masks_mb.tif')
layer = viewer.layers[f'{date}_s{sr}_ch{ch}_deconv2d_iter_2_masks_mb']
layer.contrast_limits = (0, 1)
layer.opacity = 0.2
layer.colormap = 'green'

viewer.open(f'/Users/gerard/data/confocal/{date}_Carmina/series_{sr}/channel_{ch}/{date}_s{sr}_ch{ch}_deconv2d_iter_2_masks_95.tif')
layer = viewer.layers[f'{date}_s{sr}_ch{ch}_deconv2d_iter_2_masks_95']
layer.contrast_limits = (0, 1)
layer.opacity = 0.3
layer.colormap = 'red'
