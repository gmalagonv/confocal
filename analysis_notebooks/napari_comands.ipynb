# %%
## path
import platform

#sprint(platform.node()) 



def name_home(guaricha_server = True):
    if guaricha_server:
        home = '/Users/gerard/guaricha/home/'
    else:
        system = platform.system()
        if system == 'Linux':
            home = '/home/gerard/'
        elif system == 'Darwin':
            home = '/Users/gerard/'
        elif system == "Windows":
            home = 'C:/Users/cviko/'

    home = home + 'data/confocal/'
    print(home)
    return home

# %%
home = name_home(guaricha_server = True)
date = '2026_06_15'
ch = '2'
sr = '0'
viewer.open(f'{home}{date}_Carmina/series_{sr}/channel_{ch}/{date}_s{sr}_ch{ch}_deconv2d_iter_2.tif')
viewer.open(f'{home}{date}_Carmina/series_{sr}/channel_{ch}/{date}_s{sr}_ch{ch}.tif')

viewer.open(f'{home}{date}_Carmina/series_{sr}/channel_{ch}/{date}_s{sr}_ch{ch}_deconv2d_iter_2_masks_mb.tif')
layer = viewer.layers[f'{date}_s{sr}_ch{ch}_deconv2d_iter_2_masks_mb']
layer.contrast_limits = (0, 1)
layer.opacity = 0.2
layer.colormap = 'green'

viewer.open(f'{home}{date}_Carmina/series_{sr}/channel_{ch}/{date}_s{sr}_ch{ch}_deconv2d_iter_2_masks_95.tif')
layer = viewer.layers[f'{date}_s{sr}_ch{ch}_deconv2d_iter_2_masks_95']
layer.contrast_limits = (0, 1)
layer.opacity = 0.3
layer.colormap = 'red'


#### compare deconvolutions:


home = name_home(guaricha_server = True)
date = '2026_06_15'
ch_l = ['0','1','2']

sr = '0'

for ch in ch_l:
    #viewer.open(f'{home}{date}_Carmina/series_{sr}/channel_{ch}/{date}_s{sr}_ch{ch}.tif')
    #viewer.open(f'{home}{date}_Carmina/series_{sr}/channel_{ch}/{date}_s{sr}_ch{ch}_deconv2d_iter_2.tif')
    viewer.open(f'{home}{date}_Carmina/series_{sr}/channel_{ch}/{date}_s{sr}_ch{ch}_deconv2d_psfest_blind_iter_2.tif')

    # viewer.open(f'{home}{date}_Carmina/series_{sr}/channel_{ch}/{date}_s{sr}_ch{ch}_deconv2d_gibson_iter_2.tif')
    # viewer.open(f'{home}{date}_Carmina/series_{sr}/channel_{ch}/{date}_s{sr}_ch{ch}_deconv2d_wiener.tif')
    # viewer.open(f'{home}{date}_Carmina/series_{sr}/channel_{ch}/{date}_s{sr}_ch{ch}_deconv2d_gibson_wiener.tif')

# %%
'2026_06_15_s0_ch0_deconv2d_psfest_blind_iter_2.tif'
